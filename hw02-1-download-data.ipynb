# %%
import os

os.makedirs('data', exist_ok=True)

# %%
import subprocess

subprocess.run([
    "aws", "s3", "cp",
    "s3://dsan6000-wikipedia/hourly_parquet/",
    "data/",
    "--recursive",
    "--exclude", "*",
    "--include", "*.parquet"
])
# Out:
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_060000.parquet to data/20260901_060000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_130000.parquet to data/20260901_130000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_050000.parquet to data/20260901_050000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_040000.parquet to data/20260901_040000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_090000.parquet to data/20260901_090000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_080000.parquet to data/20260901_080000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_110000.parquet to data/20260901_110000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_070000.parquet to data/20260901_070000.parquet
# download: s3://dsan6000-wikipedia/hourly_parquet/20260901_100000.parquet to data/20260901_100000.parquet
# ...

# %%
os.listdir("data")
# Out:
# ['20260901_140000.parquet',
#  '20260901_170000.parquet',
#  '20260901_150000.parquet',
#  '20260901_080000.parquet',
#  '20260902_030000.parquet',
#  '20260901_070000.parquet',
#  '20260901_160000.parquet',
#  '20260902_000000.parquet',
#  '20260901_050000.parquet',
#  '20260901_230000.parquet',
#  '20260902_010000.parquet',
#  '20260901_180000.parquet',
#  '20260902_020000.parquet',
#  '20260901_040000.parquet',
#  '20260901_210000.parquet',
#  '20260901_130000.parquet',
#  '20260901_100000.parquet',
#  '20260901_110000.parquet',
#  '20260901_200000.parquet',
#  '20260901_220000.parquet',
#  '20260901_190000.parquet',
#  '20260901_120000.parquet',
#  '20260901_090000.parquet',
#  '20260901_060000.parquet']
